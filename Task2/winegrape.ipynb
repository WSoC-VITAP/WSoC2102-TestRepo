# %%
# !unzip "/content/drive/MyDrive/WineGrape.zip"
# Out:
# Archive:  /content/drive/MyDrive/WineGrape.zip
#    creating: WineGrape/
#    creating: WineGrape/test/
#    creating: WineGrape/test/WineGrape/
#    creating: WineGrape/train/
#    creating: WineGrape/train/WineGrape/
#   inflating: WineGrape/train/WineGrape/CDY_20180427_152724818_BURST000_COVER_TOP.jpg
#   inflating: WineGrape/train/WineGrape/CDY_20180427_152724818_BURST000_COVER_TOP.txt
#   inflating: WineGrape/train/WineGrape/CDY_20180427_152823935_BURST000_COVER_TOP.jpg
#   inflating: WineGrape/train/WineGrape/CDY_20180427_152823935_BURST000_COVER_TOP.txt
#   inflating: WineGrape/train/WineGrape/CDY_20180427_152937457_BURST000_COVER_TOP.jpg
#   inflating: WineGrape/train/WineGrape/CDY_20180427_152937457_BURST000_COVER_TOP.txt
#   inflating: WineGrape/train/WineGrape/CDY_20180427_153021423_BURST001.jpg
#   inflating: WineGrape/train/WineGrape/CDY_20180427_153021423_BURST001.txt
#   inflating: WineGrape/train/WineGrape/CDY_20180427_153126820_BURST000_COVER_TOP.jpg
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9199, done.
# remote: Total 9199 (delta 0), reused 0 (delta 0), pack-reused 9199
# Receiving objects: 100% (9199/9199), 9.57 MiB | 25.33 MiB/s, done.
# Resolving deltas: 100% (6402/6402), done.

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# !python train.py --img 416 --batch 16 --epochs 30 --data ../WineGrape/WineGrape.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=../WineGrape/WineGrape.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=30, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=30
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-392-gb894e69 torch 1.9.0+cu102 CPU
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 416 --conf 0.4 --source /content/WineGrape/test/WineGrape/
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/WineGrape/test/WineGrape/, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-392-gb894e69 torch 1.9.0+cu102 CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients
# image 1/5 /content/WineGrape/test/WineGrape/Green-harvesting.png: 288x416 3 WineGrapes, Done. (0.150s)
# image 2/5 /content/WineGrape/test/WineGrape/Red_Grapes_a44fb818-6156-4955-b7db-3e7733cfac87.jpg: 224x416 Done. (0.112s)
# image 3/5 /content/WineGrape/test/WineGrape/Screen-Shot-2018-08-09-at-20.52.09.png: 256x416 2 WineGrapes, Done. (0.123s)
# ...
